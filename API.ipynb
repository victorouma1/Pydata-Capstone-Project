# %%
import requests

# %%
country = 'Kenya'
url = f"http://api.airvisual.com/v2/city?city=Los+Angeles&state=California&country=USA&key=31b00b1d-07c3-4cbd-9a7a-555bc59b03bd"
aq_response = requests.get(url)
aq_response
# Out:
# <Response [200]>

# %%
a = aq_response.json()
a
# Out:
# {'status': 'success',
#  'data': {'city': 'Los Angeles',
#   'state': 'California',
#   'country': 'USA',
#   'location': {'type': 'Point', 'coordinates': [-118.4108248, 34.0193936]},
#   'current': {'pollution': {'ts': '2026-04-08T12:00:00.000Z',
#     'aqius': 47,
#     'mainus': 'p2',
#     'aqicn': 33,
#     'maincn': 'p1'},
#    'weather': {'ts': '2026-04-08T12:00:00.000Z',
#     'ic': '03n',
#     'hu': 95,
#     'pr': 1013,
#     'tp': 15,
#     'wd': 204,
#     'ws': 1.67,
#     'heatIndex': 15}}}}

# %%
url = "https://cckpapi.worldbank.org/api/v1/cmip6-x1.0_climatology_rx5day_returnlevel10yr_annual_historical_median_ssp119,ssp126,ssp245,ssp370,ssp585_ensemble_all_mean/global_countries?_format=json"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
data = response.json()
data
# Out:
# {'metadata': {'apiVersion': 'v1', 'status': 'success', 'messages': []},
#  'data': []}
